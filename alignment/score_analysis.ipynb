# %%
import json

with open("../out/202006222159_spanishfn.json") as fp:
    data = json.load(fp)

# %%
from scipy.stats import rankdata

def rank_transform(orig):
    data = np.copy(orig)
    indices = [i for i, s in enumerate(data) if s > 0]
    norm = rankdata([data[i] for i in indices], "max") / len(indices)

    for i, s in zip(indices, norm):
        data[i] = s
    return data

# %%
import numpy as np
import pandas as pd

scaled_rank = [
    (rank_transform(np.array(x["data"]).flatten()), x["id"])
    for x in data["alignments"]
]

# %% [markdown]
# # Score techniques correlations

# %%
m = np.matrix([X for X, label in scaled_rank]).T
df = pd.DataFrame(m, columns=[label for X, label in scaled_rank])

df.corr()
# Out:
#                      name_matching  core_fe_matching  lu_wordnet    synset  \
# name_matching             1.000000          0.167571    0.084190  0.090414
# core_fe_matching          0.167571          1.000000    0.046413  0.048231
# lu_wordnet                0.084190          0.046413    1.000000  0.945605
# synset                    0.090414          0.048231    0.945605  1.000000
# synset_inv                0.096833          0.048284    0.772525  0.810133
# muse_fe_match             0.045212          0.337887    0.018468  0.020401
# muse_exact_fe_match       0.183034          0.993215    0.048899  0.050916
# lu_muse_10_0.3            0.087974          0.045758    0.305959  0.330875
# lu_muse_5_0.3             0.102747          0.043805    0.316027  0.347481
# lu_muse_3_0.3             0.112796          0.042065    0.326958  0.363508
# lu_mean_muse              0.009915          0.034919    0.206459  0.209317
# frame_def_muse            0.012267         -0.002378   -0.001974 -0.002052
#
#                      synset_inv  muse_fe_match  muse_exact_fe_match  \
# name_matching          0.096833       0.045212             0.183034
# core_fe_matching       0.048284       0.337887             0.993215
# lu_wordnet             0.772525       0.018468             0.048899
# synset                 0.810133       0.020401             0.050916
# synset_inv             1.000000       0.019611             0.051208
# muse_fe_match          0.019611       1.000000             0.332904
# muse_exact_fe_match    0.051208       0.332904             1.000000
# lu_muse_10_0.3         0.293711       0.016484             0.048362
# lu_muse_5_0.3          0.310127       0.014505             0.046718
# lu_muse_3_0.3          0.323873       0.013328             0.044893
# lu_mean_muse           0.207649       0.043994             0.035677
# frame_def_muse         0.004173       0.028583            -0.002320
#
#                      lu_muse_10_0.3  lu_muse_5_0.3  lu_muse_3_0.3  \
# name_matching              0.087974       0.102747       0.112796
# core_fe_matching           0.045758       0.043805       0.042065
# lu_wordnet                 0.305959       0.316027       0.326958
# synset                     0.330875       0.347481       0.363508
# synset_inv                 0.293711       0.310127       0.323873
# muse_fe_match              0.016484       0.014505       0.013328
# muse_exact_fe_match        0.048362       0.046718       0.044893
# lu_muse_10_0.3             1.000000       0.823111       0.724372
# lu_muse_5_0.3              0.823111       1.000000       0.880212
# lu_muse_3_0.3              0.724372       0.880212       1.000000
# lu_mean_muse               0.193122       0.157745       0.137136
# frame_def_muse            -0.006959      -0.005529      -0.004278
#
#                      lu_mean_muse  frame_def_muse
# name_matching            0.009915        0.012267
# core_fe_matching         0.034919       -0.002378
# lu_wordnet               0.206459       -0.001974
# synset                   0.209317       -0.002052
# synset_inv               0.207649        0.004173
# muse_fe_match            0.043994        0.028583
# muse_exact_fe_match      0.035677       -0.002320
# lu_muse_10_0.3           0.193122       -0.006959
# lu_muse_5_0.3            0.157745       -0.005529
# lu_muse_3_0.3            0.137136       -0.004278
# lu_mean_muse             1.000000       -0.013955
# frame_def_muse          -0.013955        1.000000

# %%
indices = data["indices"]
en_len = len(indices[0])
l2_len = len(indices[1])

sums = np.sum([X for X, label in scaled_rank], axis=0).reshape(en_len, l2_len)

# %% [markdown]
# # Best alignment pairs scored by all techniques

# %%
sum_idx = [(idx[0], idx[1], score) for idx, score in np.ndenumerate(sums)]
sorted_idx = sorted(sum_idx, key=lambda x: -x[2])

# %%
printed = 0

for x in sorted_idx:
    en_frm = data["frames"][indices[0][x[0]]]
    l2_frm = data["frames"][indices[1][x[1]]]
    
    if en_frm["name"] != l2_frm["name"] and (len(en_frm["LUs"]) > 0 and len(l2_frm["LUs"]) > 0):
        score = '{:.3f}'.format(x[2]/10)
        print(f'{score}: {(en_frm["name"]+"("+en_frm["gid"]+")").ljust(40)} {l2_frm["name"]} ({l2_frm["gid"]})')
        printed += 1
        printed += 1
        
        if printed == 50:
              break
# Out:
# 1.063: Have_as_translation_equivalent(1654.en)  Translating (1645.es)
# 1.059: Be_translation_equivalent(1655.en)       Translating (1645.es)
# 1.051: Gradable_proximity(2900.en)              Locative_relation (199.es)
# 1.047: Hearsay(37.en)                           Hear (37.es)
# 1.030: Make_agreement_on_action(1342.en)        Be_in_agreement_on_action (1380.es)
# 1.025: Renting_out(1729.en)                     Renting (1728.es)
# 1.022: Regard(1400.en)                          Opinion (1692.es)
# 1.021: Hit_target(485.en)                       Use_firearm (290.es)
# 1.019: Hit_target(485.en)                       Shoot_projectiles (289.es)
# 1.019: Renting(1728.en)                         Renting_out (1729.es)
# 0.999: Questioning(40.en)                       Request (41.es)
# 0.997: Undergo_transformation(2973.en)          Cause_change (683.es)
# 0.986: Just_found_out(2050.en)                  Stimulus_focus (280.es)
# 0.984: Locale_by_ownership(2171.en)             Locale (192.es)
# 0.983: Being_at_risk(1560.en)                   Risky_situation (1690.es)
# 0.982: Tasting(2330.en)                         Attempt (116.es)
# 0.979: Halt(1024.en)                            Cause_to_halt (1518.es)
# 0.975: Remembering_information(1220.en)         Evoking (1012.es)
# 0.974: Use_firearm(290.en)                      Shoot_projectiles (289.es)
# 0.971: Treating_and_mistreating(2770.en)        Attempt (116.es)
# 0.971: Subjective_influence(1083.en)            Influence (1679.es)
# 0.968: Motion_directional(362.en)               Motion_up_downwards (1528.es)
# 0.963: Undergo_change(1172.en)                  Cause_change (683.es)
# 0.956: Suasion(89.en)                           Attempt_suasion (332.es)
# 0.956: Delivery(1344.en)                        Giving (139.es)

# %% [markdown]
# # Worst alignment pairs compared to baseline
#
#
# The baseline in this case is name matching. This list sorts alignemnt pairs by the difference of their aggregated score and the name_matching score and only prints frame pairs with the same name (baseline).

# %%
try:
    baseline = next(np.array(x["data"]) for x in data["alignments"] if x["id"] == "name_matching")
except:
    baseline = next(np.array(x["data"]) for x in data["alignments"] if x["id"] == "id_matching")
sum_idx = [(idx[0], idx[1], score) for idx, score in np.ndenumerate(baseline - (sums / 10))]
sorted_idx = [x for x in sorted(sum_idx, key=lambda x: -x[2]) if x[2] > 0]

# %%
printed = 0

for x in sorted_idx:
    en_frm = data["frames"][indices[0][x[0]]]
    l2_frm = data["frames"][indices[1][x[1]]]
    
    if len(en_frm["LUs"]) > 0 and len(l2_frm["LUs"]) > 0:
        score = '{:.3f}'.format(1-x[2])
        print(f'{score}: {(en_frm["name"]+"("+en_frm["gid"]+")").ljust(40)} {l2_frm["name"]} ({l2_frm["gid"]})')
        printed += 1

        if printed == 50:
              break
# Out:
# 0.454: Possibility(2120.en)                     Possibility (2120.es)
# 0.464: Terrorism(1750.en)                       Terrorism (1750.es)
# 0.485: Activity_done_state(182.en)              Activity_done_state (182.es)
# 0.508: Turning_out(2191.en)                     Turning_out (2191.es)
# 0.554: Path_shape(61.en)                        Path_shape (61.es)
# 0.570: Distinctiveness(1133.en)                 Distinctiveness (1133.es)
# 0.575: Process_completed_state(234.en)          Process_completed_state (234.es)
# 0.650: Impact(311.en)                           Impact (311.es)
# 0.651: Buildings(173.en)                        Buildings (173.es)
# 0.712: Leadership(73.en)                        Leadership (73.es)
# 0.735: Activity_prepare(170.en)                 Activity_prepare (170.es)
# 0.760: Commerce_collect(210.en)                 Commerce_collect (210.es)
# 0.767: Estimating(1513.en)                      Estimating (1513.es)
# 0.774: Substance_by_phase(385.en)               Substance_by_phase (385.es)
# 0.778: Motion(7.en)                             Motion (7.es)
# 0.779: Performers_and_roles(413.en)             Performers_and_roles (413.es)
# 0.781: Process_resume(148.en)                   Process_resume (148.es)
# 0.785: Fluidic_motion(345.en)                   Fluidic_motion (482.es)
# 0.794: Statement(43.en)                         Statement (43.es)
# 0.794: Emptying(58.en)                          Emptying (58.es)
# 0.798: Kinship(104.en)                          Kinship (104.es)
# 0.800: Measurable_attributes(965.en)            Measurable_attributes (965.es)
# 0.808: Change_of_phase(336.en)                  Change_of_phase (336.es)
# 0.810: Locale_by_use(196.en)                    Locale_by_use (196.es)
# 0.814: Stimulus_focus(364.en)                   Stimulus_focus (280.es)
# 0.826: Process_continue(145.en)                 Process_continue (145.es)
# 0.831: Avoiding(274.en)                         Avoiding (274.es)
# 0.834: Bragging(1624.en)                        Bragging (1624.es)
# 0.839: Becoming(2971.en)                        Becoming (1070.es)
# 0.839: Body_movement(16.en)                     Body_movement (16.es)
# 0.848: Process_start(133.en)                    Process_start (133.es)
# 0.851: Perception_body(68.en)                   Perception_body (68.es)
# 0.851: Fining(223.en)                           Fining (223.es)
# 0.853: Memorization(1132.en)                    Memorization (1132.es)
# 0.861: Change_direction(1653.en)                Change_direction (1607.es)
# 0.863: Make_cognitive_connection(252.en)        Make_cognitive_connection (252.es)
# 0.875: Soaking(333.en)                          Soaking (333.es)
# 0.878: Process(233.en)                          Process (233.es)
# 0.882: Emitting(359.en)                         Emitting (502.es)
# 0.883: Locale_by_event(1921.en)                 Locale_by_event (1921.es)
# 0.884: Contacting(286.en)                       Contacting (452.es)
# 0.885: Change_posture(770.en)                   Change_posture (422.es)
# 0.892: Precipitation(314.en)                    Precipitation (314.es)
# 0.895: Departing(57.en)                         Departing (57.es)
# 0.896: Traversing(1310.en)                      Traversing (1310.es)
# 0.898: Being_at_risk(1560.en)                   Being_at_risk (1688.es)
# 0.910: Taking_sides(1306.en)                    Taking_sides (1306.es)
# 0.916: Judgment_communication(219.en)           Judgment_communication (219.es)
# 0.928: Cause_to_move_in_place(276.en)           Cause_to_move_in_place (363.es)
# 0.935: People_by_age(973.en)                    People_by_age (973.es)

# %%
import networkx as nx

def min_matching(scores):
    G = nx.Graph()

    G.add_nodes_from(indices[0])
    G.add_nodes_from(indices[1])

    edge_matrix = scores.reshape(en_len, l2_len)
    G.add_edges_from([
        (indices[0][idx[0]], indices[1][idx[1]], { "weight": 1-score })
        for idx, score in np.ndenumerate(edge_matrix)
    ])
    
    m = nx.bipartite.minimum_weight_full_matching(G, top_nodes=indices[0])
    return {k:v for k, v in m.items() if k.endswith(".en")}

# %%
import time

matchings = []

for X, label in scaled_rank:
    start = time.time()
    matchings.append(min_matching(X))

    print(f'Computed matching for {label}')
    print("--- %s seconds ---" % (time.time() - start))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-367207bb395e> in <module>
#       5 for X, label in scaled_rank:
#       6     start = time.time()
# ----> 7     matchings.append(min_matching(X))
#       8
#       9     print(f'Computed matching for {label}')
#
# <ipython-input-10-aae1b93160e5> in min_matching(scores)
#      13     ])
#      14
# ---> 15     m = nx.bipartite.minimum_weight_full_matching(G, top_nodes=indices[0])
#      16     return {k:v for k, v in m.items() if k.endswith(".en")}
#
# AttributeError: module 'networkx.algorithms.bipartite' has no attribute 'minimum_weight_full_matching'

# %%
votes = {}

for m in matchings[1:]:
    for k,v in m.items():
        if (k, v) in votes:
            votes[(k, v)] += 1
        else:
            votes[(k, v)] = 1

# %%
len(matchings)-1

# %%
sorted_idx = sorted([(k[0], k[1], v) for k, v in votes.items()], key=lambda x: -x[2])

# %%
printed = 0

for x in sorted_idx:
    if x[2] <= 3:
        continue
    
    en_frm = data["frames"][x[0]]
    l2_frm = data["frames"][x[1]]
    
    if en_frm["name"] != l2_frm["name"]:
        score = '{:d}'.format(x[2])
        print(f'{score}: {(en_frm["name"]+"("+en_frm["gid"]+")").ljust(40)} {l2_frm["name"]} ({l2_frm["gid"]})')
        printed += 1

        if printed == 100:
              break
