# %%
import json

with open("./out/202003021204_fnbrasil.json") as fp:
    data = json.load(fp)

# %%
from scipy.stats import rankdata

def rank_transform(orig):
    data = np.copy(orig)
    indices = [i for i, s in enumerate(data) if s > 0]
    norm = rankdata([data[i] for i in indices], "max") / len(indices)

    for i, s in zip(indices, norm):
        data[i] = s
    return data

# %%
import numpy as np
import pandas as pd

scaled_rank = [
    (rank_transform(np.array(x["data"]).flatten()), x["id"])
    for x in data["alignments"]
]

# %% [markdown]
# # Score techniques correlations

# %%
m = np.matrix([X for X, label in scaled_rank]).T
df = pd.DataFrame(m, columns=[label for X, label in scaled_rank])

df.corr()
# Out:
#                      id_matching  core_fe_matching  lu_wordnet    synset  \
# id_matching             1.000000          0.162606    0.062533  0.070130
# core_fe_matching        0.162606          1.000000   -0.001662 -0.000679
# lu_wordnet              0.062533         -0.001662    1.000000  0.935412
# synset                  0.070130         -0.000679    0.935412  1.000000
# synset_inv              0.079656         -0.000157    0.768259  0.817910
# muse_fe_match           0.045581          0.294834   -0.002540 -0.000322
# muse_exact_fe_match     0.176351          0.992487   -0.001129 -0.000071
# muse_mixed_fe_match     0.094832          0.077496    0.057293  0.058748
# lu_muse_10_0.3          0.042546         -0.004614    0.266579  0.280054
# lu_muse_5_0.3           0.051930         -0.002653    0.269590  0.297481
# lu_mean_muse            0.007858         -0.043992    0.173931  0.177716
# frame_def_muse          0.008921         -0.058701    0.042128  0.042052
#
#                      synset_inv  muse_fe_match  muse_exact_fe_match  \
# id_matching            0.079656       0.045581             0.176351
# core_fe_matching      -0.000157       0.294834             0.992487
# lu_wordnet             0.768259      -0.002540            -0.001129
# synset                 0.817910      -0.000322            -0.000071
# synset_inv             1.000000       0.000111             0.000456
# muse_fe_match          0.000111       1.000000             0.291920
# muse_exact_fe_match    0.000456       0.291920             1.000000
# muse_mixed_fe_match    0.061999       0.081699             0.084586
# lu_muse_10_0.3         0.241557      -0.005304            -0.004215
# lu_muse_5_0.3          0.262595      -0.002048            -0.002258
# lu_mean_muse           0.175500      -0.044451            -0.042564
# frame_def_muse         0.042711      -0.084689            -0.056606
#
#                      muse_mixed_fe_match  lu_muse_10_0.3  lu_muse_5_0.3  \
# id_matching                     0.094832        0.042546       0.051930
# core_fe_matching                0.077496       -0.004614      -0.002653
# lu_wordnet                      0.057293        0.266579       0.269590
# synset                          0.058748        0.280054       0.297481
# synset_inv                      0.061999        0.241557       0.262595
# muse_fe_match                   0.081699       -0.005304      -0.002048
# muse_exact_fe_match             0.084586       -0.004215      -0.002258
# muse_mixed_fe_match             1.000000        0.061300       0.051763
# lu_muse_10_0.3                  0.061300        1.000000       0.796981
# lu_muse_5_0.3                   0.051763        0.796981       1.000000
# lu_mean_muse                    0.397582        0.193374       0.158204
# frame_def_muse                  0.577491        0.046377       0.037804
#
#                      lu_mean_muse  frame_def_muse
# id_matching              0.007858        0.008921
# core_fe_matching        -0.043992       -0.058701
# lu_wordnet               0.173931        0.042128
# synset                   0.177716        0.042052
# synset_inv               0.175500        0.042711
# muse_fe_match           -0.044451       -0.084689
# muse_exact_fe_match     -0.042564       -0.056606
# muse_mixed_fe_match      0.397582        0.577491
# lu_muse_10_0.3           0.193374        0.046377
# lu_muse_5_0.3            0.158204        0.037804
# lu_mean_muse             1.000000        0.304607
# frame_def_muse           0.304607        1.000000

# %%
indices = data["indices"]
en_len = len(indices[0])
l2_len = len(indices[1])

sums = np.sum([X for X, label in scaled_rank], axis=0).reshape(en_len, l2_len)

# %% [markdown]
# # Best alignment pairs scored by all techniques

# %%
sum_idx = [(idx[0], idx[1], score) for idx, score in np.ndenumerate(sums)]
sorted_idx = sorted(sum_idx, key=lambda x: -x[2])

# %%
printed = 0

for x in sorted_idx:
    en_frm = data["frames"][indices[0][x[0]]]
    l2_frm = data["frames"][indices[1][x[1]]]
    
    if en_frm["name"] != l2_frm["name"]:
        score = '{:.3f}'.format(x[2]/10)
        print(f'{score}: {(en_frm["name"]+"("+en_frm["gid"]+")").ljust(40)} {l2_frm["name"]} ({l2_frm["gid"]})')
        printed += 1
        printed += 1
        
        if printed == 50:
              break
# Out:
# 1.076: Intentionally_create(280.en)             Intentionally_create# (280.pt)
# 1.033: Assistance(391.en)                       Assistance# (391.pt)
# 1.018: Linguistic_meaning(406.en)               Linguistic_meaning# (406.pt)
# 1.014: Creating(319.en)                         Creating# (319.pt)
# 0.993: Cutting(265.en)                          Cortar__Cutting (265.pt)
# 0.993: Performers_and_roles(413.en)             Performers_and_roles# (413.pt)
# 0.992: Studying(1130.en)                        Estudar__Studying (1130.pt)
# 0.985: Competition(241.en)                      Competition# (241.pt)
# 0.981: Perception_experience(70.en)             Perception_experience# (70.pt)
# 0.981: Cause_to_be_included(2230.en)            Causar_estar_incluído__Cause_to_be_included (2230.pt)
# 0.975: Satisfying(2233.en)                      Satisfatório___Satisfying (2233.pt)
# 0.973: Abandonment(2031.en)                     Abandono__Abandonment (2031.pt)
# 0.970: Feigning(12.en)                          Fingir__Feigning (12.pt)
# 0.958: Categorization(21.en)                    Categorization# (21.pt)
# 0.958: Creating(319.en)                         Intentionally_create# (280.pt)
# 0.957: Purpose(513.en)                          Finalidade__Purpose (513.pt)
# 0.954: Chatting(910.en)                         Chatting# (910.pt)
# 0.954: Abusing(482.en)                          Abusar__Abusing (482.pt)
# 0.953: Cause_to_be_sharp(1291.en)               Causar_ficar_afiado__Cause_to_be_sharp (1291.pt)
# 0.950: Activity_ready_state(169.en)             Atividade_preparada__Activity_ready_state (169.pt)
# 0.942: Activity_start(146.en)                   Atividade_iniciar__Activity_start (146.pt)
# 0.934: Work(1892.en)                            Trabalhar__Work (1892.pt)
# 0.932: Reading_perception(279.en)               Ler__Reading (279.pt)
# 0.931: Desiring(366.en)                         Desejar__Desiring (366.pt)
# 0.929: Alternatives(1931.en)                    Possibilidades__Possibilities (1931.pt)

# %% [markdown]
# # Worst alignment pairs compared to baseline
#
#
# The baseline in this case is name matching. This list sorts alignemnt pairs by the difference of their aggregated score and the name_matching score and only prints frame pairs with the same name (baseline).

# %%
try:
    baseline = next(np.array(x["data"]) for x in data["alignments"] if x["id"] == "name_matching")
except:
    baseline = next(np.array(x["data"]) for x in data["alignments"] if x["id"] == "id_matching")
sum_idx = [(idx[0], idx[1], score) for idx, score in np.ndenumerate(baseline - (sums / 10))]
sorted_idx = [x for x in sorted(sum_idx, key=lambda x: -x[2]) if x[2] > 0]

# %%
printed = 0

for x in sorted_idx:
    en_frm = data["frames"][indices[0][x[0]]]
    l2_frm = data["frames"][indices[1][x[1]]]
    
    if len(en_frm["LUs"]) > 0 and len(l2_frm["LUs"]) > 0:
        score = '{:.3f}'.format(1-x[2])
        print(f'{score}: {(en_frm["name"]+"("+en_frm["gid"]+")").ljust(40)} {l2_frm["name"]} ({l2_frm["gid"]})')
        printed += 1

        if printed == 50:
              break
# Out:
# 0.187: Counterattack(2677.en)                   Digestão__Digestion (2677.pt)
# 0.246: Possibility(2120.en)                     Possibilidade__Possibility (2120.pt)
# 0.373: Responsibility(2657.en)                  Causar_ficar_molhado__Cause_to_be_wet (2657.pt)
# 0.377: Mass_motion(284.en)                      Massa_movimento   Mass_motion (284.pt)
# 0.397: Preference(1626.en)                      Preferência__Preference (1626.pt)
# 0.431: Adding_up(621.en)                        Adição__Adding_up (621.pt)
# 0.452: Process_end(232.en)                      Processo_fim [Process_end]# (232.pt)
# 0.471: Assessing(519.en)                        Avaliar__Assessing# (519.pt)
# 0.475: Body_description_part(235.en)            Descrição_parte_do_corpo__Body_description_part (235.pt)
# 0.478: Containing(397.en)                       Conter (397.pt)
# 0.479: Activity_pause(167.en)                   Atividade_pausar__Activity_pause (167.pt)
# 0.488: Correctness(1512.en)                     Correção    Correctness (1512.pt)
# 0.545: Sleep(264.en)                            Dormir    Sleep (264.pt)
# 0.581: Leadership(73.en)                        Liderança__Leadership (73.pt)
# 0.596: Statement(43.en)                         Declaração__Statement (43.pt)
# 0.604: Process_continue(145.en)                 Process_continue# (145.pt)
# 0.614: Emotions_of_mental_activity(2045.en)     Emoções_de_atividade_mental__Emotions_of_mental_activity (2045.pt)
# 0.630: Performing_arts(405.en)                  Performar_artes__Performing_arts (405.pt)
# 0.637: Attaching(197.en)                        Anexar   Attaching (197.pt)
# 0.637: Locative_relation(199.en)                Locativo_relação__Locative_relation (199.pt)
# 0.638: Being_obligated(392.en)                  Ser_obrigado (392.pt)
# 0.638: Bringing(240.en)                         Transportar__Bringing (240.pt)
# 0.642: Cogitation(22.en)                        Cogitation# (22.pt)
# 0.643: Accompaniment(258.en)                    Acompanhamento__Accompaniment (258.pt)
# 0.644: Accomplishment(1519.en)                  Realização__Accomplishment (1519.pt)
# 0.651: Mental_property(29.en)                   Característica_mental__Mental_property (29.pt)
# 0.656: Abundance(1602.en)                       Abundância__Abundance (1602.pt)
# 0.673: Experiencer_focus(48.en)                 Experienciador_foco__Experiencer_focus (48.pt)
# 0.673: Experiencer_obj(47.en)                   Experienciador_objeto__Experiencer_obj (47.pt)
# 0.674: Withdraw_from_participation(1518.en)     Retirar_da_participação__Withdraw_from_participation (1518.pt)
# 0.675: Arranging(921.en)                        Arrumar__Arranging (921.pt)
# 0.685: Existence(660.en)                        Existence# (660.pt)
# 0.690: Judgment(28.en)                          Julgamento__Judgment# (28.pt)
# 0.715: Self_motion(64.en)                       Auto_movimento__Self_motion (64.pt)
# 0.721: Prevarication(287.en)                    Prevaricação__Prevarication (287.pt)
# 0.721: Touring(1907.en)                         Turismo__Touring (1907.pt)
# 0.725: Process_start(133.en)                    Processo_iniciado__Process_start (133.pt)
# 0.726: Attempt_suasion(87.en)                   Tentativa_de_persuasão__Attempt_suasion# (87.pt)
# 0.728: Intentionally_act(198.en)                Agir_intencionalmente__Intentionally_act (198.pt)
# 0.733: Familiarity(1597.en)                     Familiaridade__Familiarity (1597.pt)
# 0.735: Activity_stop(166.en)                    Atividade_interromper__Activity_stop (166.pt)
# 0.745: Cause_to_be_dry(337.en)                  Causar_ficar_seco__Cause_to_be_dry (337.pt)
# 0.751: Cause_to_end(1149.en)                    Causar_terminar__Cause_to_end (1149.pt)
# 0.761: Ride_vehicle(690.en)                     Ride_vehicle# (690.pt)
# 0.775: Possession(118.en)                       Posse__Possession (118.pt)
# 0.778: Mental_stimulus_exp_focus(2044.en)       Mental_stimulus_exp_focus# (2044.pt)
# 0.779: Request(41.en)                           Pedir__Asking (41.pt)
# 0.780: Becoming_aware(20.en)                    Tornar-se_consciente__Becoming_aware (20.pt)
# 0.781: Make_noise(69.en)                        Make_noise# (69.pt)
# 0.787: Giving(139.en)                           Dar__Giving (139.pt)

# %%
import networkx as nx

def min_matching(scores):
    G = nx.Graph()

    G.add_nodes_from(indices[0])
    G.add_nodes_from(indices[1])

    edge_matrix = scores.reshape(en_len, l2_len)
    G.add_edges_from([
        (indices[0][idx[0]], indices[1][idx[1]], { "weight": 1-score })
        for idx, score in np.ndenumerate(edge_matrix)
    ])
    
    m = nx.bipartite.minimum_weight_full_matching(G, top_nodes=indices[0])
    return {k:v for k, v in m.items() if k.endswith(".en")}

# %%
import time

matchings = []

for X, label in scaled_rank:
    start = time.time()
    matchings.append(min_matching(X))

    print(f'Computed matching for {label}')
    print("--- %s seconds ---" % (time.time() - start))
# Out:
# Computed matching for id_matching
# --- 11.72362494468689 seconds ---
# Computed matching for core_fe_matching
# --- 47.562856912612915 seconds ---
# Computed matching for lu_wordnet
# --- 42.738417863845825 seconds ---
# Computed matching for synset
# --- 39.50200295448303 seconds ---
# Computed matching for synset_inv
# --- 37.680036783218384 seconds ---
# Computed matching for muse_fe_match
# --- 88.11011409759521 seconds ---
# Computed matching for muse_exact_fe_match
# --- 49.988282203674316 seconds ---
# Computed matching for muse_mixed_fe_match
# --- 46.5916748046875 seconds ---
# Computed matching for lu_muse_10_0.3
# --- 38.30361795425415 seconds ---
# Computed matching for lu_muse_5_0.3
# --- 36.21912717819214 seconds ---
# Computed matching for lu_mean_muse
# --- 42.37503123283386 seconds ---
# Computed matching for frame_def_muse
# --- 700.685142993927 seconds ---

# %%
votes = {}

for m in matchings[1:]:
    for k,v in m.items():
        if (k, v) in votes:
            votes[(k, v)] += 1
        else:
            votes[(k, v)] = 1

# %%
len(matchings)-1
# Out:
# 11

# %%
sorted_idx = sorted([(k[0], k[1], v) for k, v in votes.items()], key=lambda x: -x[2])

# %%
printed = 0

for x in sorted_idx:
    if x[2] <= 3:
        continue
    
    en_frm = data["frames"][x[0]]
    l2_frm = data["frames"][x[1]]
    
    if en_frm["name"] != l2_frm["name"]:
        score = '{:d}'.format(x[2])
        print(f'{score}: {(en_frm["name"]+"("+en_frm["gid"]+")").ljust(40)} {l2_frm["name"]} ({l2_frm["gid"]})')
        printed += 1

        if printed == 100:
              break
# Out:
# 8: Assistance(391.en)                       Assistance# (391.pt)
# 8: Participation(1144.en)                   Participation# (1144.pt)
# 8: Abusing(482.en)                          Abusar__Abusing (482.pt)
# 8: Activity_ready_state(169.en)             Atividade_preparada__Activity_ready_state (169.pt)
# 7: Kinship(104.en)                          Kinship# (104.pt)
# 7: Abandonment(2031.en)                     Abandono__Abandonment (2031.pt)
# 6: Linguistic_meaning(406.en)               Linguistic_meaning# (406.pt)
# 6: Categorization(21.en)                    Categorization# (21.pt)
# 6: Cause_to_experience(288.en)              Emoções_de_atividade_mental__Emotions_of_mental_activity (2045.pt)
# 6: Feigning(12.en)                          Fingir__Feigning (12.pt)
# 6: Prevarication(287.en)                    Prevaricação__Prevarication (287.pt)
# 6: Activity_start(146.en)                   Atividade_iniciar__Activity_start (146.pt)
# 6: Money(1761.en)                           Dinheiro__Money (1761.pt)
# 6: Studying(1130.en)                        Estudar__Studying (1130.pt)
# 6: Cause_to_be_sharp(1291.en)               Causar_ficar_afiado__Cause_to_be_sharp (1291.pt)
# 6: Experiencer_obj(47.en)                   Experienciador_objeto__Experiencer_obj (47.pt)
# 5: Clemency(1086.en)                        Clemency# (1086.pt)
# 5: Toxic_substance(1163.en)                 Toxic_substance# (1163.pt)
# 5: Front_for(1734.en)                       Front_for# (1734.pt)
# 5: Hair_configuration(126.en)               Hair_configuration# (126.pt)
# 5: Clothing(134.en)                         Clothing# (134.pt)
# 5: Temperature(1050.en)                     Temperature# (1050.pt)
# 5: Examination(107.en)                      Examination# (107.pt)
# 5: Non-commutative_statement(2247.en)       Non-commutative_statement# (2247.pt)
# 5: Legal_rulings(2076.en)                   Ruling_legally# (2076.pt)
# 5: Rebellion(2584.en)                       Rebellion# (2584.pt)
# 5: Passing(2071.en)                         Passing# (2071.pt)
# 5: Killing(590.en)                          Killing# (590.pt)
# 5: Revolution(2585.en)                      Revolution# (2585.pt)
# 5: Revenge(347.en)                          Revenge# (347.pt)
# 5: Quitting(325.en)                         Quitting# (325.pt)
# 5: Receive_visitor_scenario(1950.en)        Receive_visitor_scenario# (1950.pt)
# 5: Reporting(483.en)                        Reporting# (483.pt)
# 5: Prison(387.en)                           Prison# (387.pt)
# 5: Operating_a_system(1495.en)              Operating_a_system# (1495.pt)
# 5: Sleep_wake_cycle(294.en)                 Sleep_wake_cycle# (294.pt)
# 5: Nuclear_process(1926.en)                 Nuclear_process# (1926.pt)
# 5: Change_operational_state(1688.en)        Change_operational_state# (1688.pt)
# 5: Temporal_collocation(1895.en)            Temporal_collocation# (1895.pt)
# 5: Unemployment_rate(1606.en)               Unemployment_rate# (1606.pt)
# 5: Evidence(25.en)                          Evidence# (25.pt)
# 5: Motion_noise(60.en)                      Motion_noise# (60.pt)
# 5: Bounded_entity(237.en)                   Bounded_entity# (237.pt)
# 5: Repel(2026.en)                           Repel# (2026.pt)
# 5: First_experience(1027.en)                First_experience# (1027.pt)
# 5: Suspicion(503.en)                        Suspicion# (503.pt)
# 5: Respond_to_proposal(1623.en)             Respond_to_proposal# (1623.pt)
# 5: Exporting(1568.en)                       Exporting# (1568.pt)
# 5: Being_named(228.en)                      Being_named# (228.pt)
# 5: Rate_description(2421.en)                Rate_description# (2421.pt)
# 5: Sociability(74.en)                       Sociability# (74.pt)
# 5: People_by_age(973.en)                    People_by_age# (973.pt)
# 5: Amassing(1482.en)                        Amassing# (1482.pt)
# 5: Collaboration(418.en)                    Collaboration# (418.pt)
# 5: Giving_in(1497.en)                       Giving_in# (1497.pt)
# 5: Margin_of_resolution(1562.en)            Clarity_of_resolution# (1562.pt)
# 5: Have_associated(1933.en)                 Have_associated# (1933.pt)
# 5: Name_conferral(221.en)                   Name_conferral# (221.pt)
# 5: Protest(2587.en)                         Protest# (2587.pt)
# 5: Dough_rising(1421.en)                    Dough_rising# (1421.pt)
# 5: Social_connection(253.en)                Social_connection# (253.pt)
# 5: Subordinates_and_superiors(530.en)       Subordinates_and_superiors# (530.pt)
# 5: Planting(2015.en)                        Planting# (2015.pt)
# 5: First_rank(402.en)                       First_rank# (402.pt)
# 5: Extradition(1370.en)                     Extradition# (1370.pt)
# 5: People_by_religion(1021.en)              People_by_religion# (1021.pt)
# 5: Temporary_group(2588.en)                 Temporary_group# (2588.pt)
# 5: Fields(1345.en)                          Fields# (1345.pt)
# 5: Sidereal_appearance(1430.en)             Sidereal_appearance# (1430.pt)
# 5: Defending(1330.en)                       Defend# (1330.pt)
# 5: Piracy(123.en)                           Piracy# (123.pt)
# 5: Contrition(382.en)                       Contrition# (382.pt)
# 5: Building(259.en)                         Building# (259.pt)
# 5: Estimating(1513.en)                      Estimating# (1513.pt)
# 5: Importance(407.en)                       Importance# (407.pt)
# 5: Shooting_scenario(1727.en)               Shooting_scenario# (1727.pt)
# 5: Claim_ownership(550.en)                  Claim_ownership# (550.pt)
# 5: Speak_on_topic(523.en)                   Speak_on_topic# (523.pt)
# 5: Gesture(36.en)                           Gesture# (36.pt)
# 5: Rite(301.en)                             Rite# (301.pt)
# 5: System(1610.en)                          System# (1610.pt)
# 5: Change_direction(1653.en)                Change_direction# (1653.pt)
# 5: Quarreling(710.en)                       Quarreling# (710.pt)
# 5: Talking_into(90.en)                      Talking_into# (90.pt)
# 5: Judgment_communication(219.en)           Judgment_communication# (219.pt)
# 5: Change_posture(770.en)                   Change_posture# (770.pt)
# 5: Evaluative_comparison(353.en)            Evaluative_comparison# (353.pt)
# 5: Religious_belief(1019.en)                Religious_belief# (1019.pt)
# 5: Thriving(1771.en)                        Thriving# (1771.pt)
# 5: Law(950.en)                              Law# (950.pt)
# 5: Resurrection(1413.en)                    Resurrection# (1413.pt)
# 5: Hunting(2006.en)                         Hunting# (2006.pt)
# 5: Replacing(1121.en)                       Replacing# (1121.pt)
# 5: Surpassing(358.en)                       Surpassing# (358.pt)
# 5: Beyond_compare(356.en)                   Beyond_compare# (356.pt)
# 5: Using(1141.en)                           Using# (1141.pt)
# 5: Travel(343.en)                           Travel# (343.pt)
# 5: Supporting(2000.en)                      Supporting# (2000.pt)
# 5: Choosing(352.en)                         Choosing# (352.pt)
# 5: Suitability(368.en)                      Suitability# (368.pt)
